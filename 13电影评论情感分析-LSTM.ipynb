# %%
# 导入需要用的库
import os
import tarfile
# 软件包的解压
import urllib.request
#网络下载的请求
import tensorflow as tf
import numpy as np

import re
# 正则化
import string

from random import randint

# %%
# 数据地址
url='http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz'
filepath='data/aclImdb_v1.tar.gz'

# %%
# 如果当前目录下不存在data文件夹，则建立
if not os.path.exists('data'):
    os.makedirs('data')
# 下载数据，80兆左右
if not os.path.isfile(filepath):
    print('downloading...')
    result=urllib.request.urlretrieve(url,filepath)
    print('downloaded:',result)
else:
    print(filepath,'is existed')
# Out:
# data/aclImdb_v1.tar.gz is existed

# %%
# 解压数据
if not os.path.exists('data/aclImdb'):
    tfile=tarfile.open(filepath,'r:gz')
    print('extracting...')
    result=tfile.extractall('data/')
    print('extraction completed')
else:
    print('data/aclImdb is existed!')
# Out:
# data/aclImdb is existed!

# %%
# 将文本中不需要的字符清除，如html中的标签<br />
def remove_tags(text):
    re_tag=re.compile(r'<[^>]+>')
    return re_tag.sub('',text)

# %%
def read_files(filetype):
    path='data/aclImdb/'
    file_list=[]
    # 读取正面评价的文件路径，存到file_list列表里
    positive_path=path+filetype+'/pos/'
    for f in os.listdir(positive_path):
        file_list+=[positive_path+f]
    pos_files_num=len(file_list)
    # 读取负面评价的文件的路径，存到file_list列表里
    negative_path=path+filetype+'/neg/'
    for  f in os.listdir(negative_path):
        file_list+=[negative_path+f]
    neg_files_num=len(file_list)-pos_files_num
    
    print('read',filetype,'files:',len(file_list))
    print(pos_files_num,'pos files in',filetype,'files')
    print(neg_files_num,'neg files in',filetype,'files')
    #得到所有标签。标签用one——hot编码，正面{1,0}负面[0,1]
    all_labels=([[1,0]]*pos_files_num+[[0,1]]*neg_files_num)
    
    # 得到所有文本
    all_texts=[]
    for fi in file_list:
        with open(fi,encoding='utf8') as file_input:
            #文本中有<br />这类html标签，将文本传入remove_tags函数
            #函数里用正则表达式将标签去除
            all_texts+=[remove_tags(''.join(file_input.readlines()))]
    return all_labels,all_texts

# %%
train_labels,train_texts=read_files("train")
test_labels,test_texts=read_files('test')
# Out:
# read train files: 25000
# 12500 pos files in train files
# 12500 neg files in train files
# read test files: 25000
# 12500 pos files in test files
# 12500 neg files in test files

# %% [markdown]
# # 建立词汇词典 Token

# %%
token=tf.keras.preprocessing.text.Tokenizer(num_words=4000)
# 分词器，把出现率最高的4000个词纳入分词器

# %%
token.fit_on_texts(train_texts)

# %%
# 查看token读取了多少文档
token.document_count
# Out:
# 25000

# %%
#print(token.word_index)# 出现频率的排名

# %%
token.word_docs
# 将单词映射为他们在训练器出现的文档或文本的数量
# Out:
# defaultdict(int,
#             {'at': 12936,
#              'satire': 209,
#              'me': 7329,
#              "isn't": 2587,
#              'pomp': 8,
#              'teachers': 64,
#              'scramble': 6,
#              'down': 3092,
#              'far': 2551,
#              'right': 2772,
#              'closer': 190,
#              'your': 4266,
#              'a': 24173,
#              'line': 1613,
#              'here': 4199,
#              "i'm": 3655,
#              'years': 3638,
#              'insightful': 63,
#              'repeatedly': 117,
#              'cartoon': 367,
#              'which': 7572,
#              'one': 14096,
#              'sack': 42,
#              'think': 5440,
#              'tried': 704,
#              'knew': 822,
#              'pity': 225,
#              'to': 23474,
#              'in': 22036,
#              'comedy': 2337,
#              'time': 8719,
#              'through': 3992,
#              'that': 20039,
#              'profession': 61,
#              'programs': 62,
#              'my': 8106,
#              'schools': 56,
#              'lead': 1170,
#              'is': 22425,
#              'burn': 125,
#              'pettiness': 2,
#              "teachers'": 1,
#              'the': 24792,
#              'it': 21332,
#              'reality': 793,
#              'same': 3323,
#              'who': 11132,
#              'about': 10490,
#              'much': 7084,
#              'of': 23726,
#              'high': 1837,
#              'survive': 239,
#              'and': 24161,
#              'fetched': 98,
#              'their': 6982,
#              'bromwell': 4,
#              "high's": 1,
#              'expect': 1066,
#              'ran': 225,
#              'other': 6679,
#              'age': 966,
#              'life': 4576,
#              'as': 16116,
#              'immediately': 434,
#              'when': 9027,
#              'adults': 330,
#              'all': 13069,
#              'i': 19225,
#              'welcome': 204,
#              'student': 322,
#              'pathetic': 431,
#              'what': 9634,
#              'situation': 600,
#              '35': 94,
#              'teaching': 78,
#              'financially': 28,
#              'whole': 2641,
#              'episode': 984,
#              'many': 5067,
#              'recalled': 18,
#              'can': 7851,
#              'some': 9644,
#              'see': 8080,
#              'saw': 2756,
#              'inspector': 110,
#              'classic': 1543,
#              'school': 1240,
#              'believe': 2209,
#              'such': 4022,
#              'students': 276,
#              'remind': 152,
#              'than': 7117,
#              'ex': 405,
#              'just': 10545,
#              'step': 310,
#              'hand': 1088,
#              'issue': 253,
#              'reaching': 92,
#              'world': 2784,
#              'shows': 1913,
#              'kids': 1249,
#              'characters': 5035,
#              'her': 6456,
#              'bet': 220,
#              'make': 6127,
#              "brooks'": 17,
#              'will': 6244,
#              'know': 4774,
#              'things': 2995,
#              'racism': 118,
#              'leg': 87,
#              'should': 4037,
#              'were': 6771,
#              'future': 757,
#              'buildings': 90,
#              'homelessness': 7,
#              'bathroom': 103,
#              'street': 558,
#              'rival': 144,
#              'where': 4730,
#              'they': 10362,
#              'move': 672,
#              'using': 731,
#              'sets': 792,
#              'by': 11719,
#              'forehead': 23,
#              'vote': 212,
#              'written': 1462,
#              'end': 4536,
#              'given': 1630,
#              'fumes': 4,
#              'flight': 136,
#              'help': 1623,
#              'woman': 2008,
#              "can't": 3017,
#              "bolt's": 1,
#              'technology': 197,
#              'month': 135,
#              'while': 4091,
#              'between': 2744,
#              'bolt': 16,
#              'stinks': 91,
#              'losing': 206,
#              'warren': 95,
#              'on': 15710,
#              'more': 9063,
#              'show': 3333,
#              'everything': 2019,
#              'name': 1386,
#              'man': 3790,
#              "they'll": 118,
#              'used': 1656,
#              'going': 3380,
#              'with': 17462,
#              'plan': 381,
#              'wants': 1124,
#              'luxuries': 3,
#              'maybe': 1976,
#              'project': 439,
#              'never': 5015,
#              'lesley': 12,
#              'live': 1349,
#              'lesson': 230,
#              'until': 1615,
#              'wilson': 141,
#              'computer': 355,
#              'fight': 903,
#              'saddles': 19,
#              'vagrant': 3,
#              'film': 13822,
#              'blazing': 42,
#              'work': 3515,
#              'agreements': 4,
#              'iraq': 66,
#              'money': 1955,
#              'side': 1102,
#              'compared': 516,
#              'most': 6509,
#              'slapstick': 157,
#              'matter': 1037,
#              'others': 1434,
#              'stated': 128,
#              'necessary': 309,
#              'deciding': 52,
#              'after': 5780,
#              'spaceballs': 10,
#              "bet's": 2,
#              'killed': 916,
#              'tender': 96,
#              'those': 3769,
#              'pictures': 394,
#              'mutual': 61,
#              'be': 14135,
#              'human': 1264,
#              'has': 10063,
#              'valuable': 88,
#              'sailor': 39,
#              'morris': 58,
#              "wasn't": 1927,
#              'succeed': 145,
#              'thrown': 388,
#              'once': 2079,
#              'something': 4061,
#              'days': 1153,
#              'do': 6639,
#              'off': 4635,
#              'he': 9899,
#              'young': 2708,
#              'thirty': 133,
#              'including': 967,
#              'monopoly': 9,
#              'carlin': 10,
#              'succeeds': 160,
#              'homeless': 92,
#              'did': 4747,
#              'home': 1533,
#              'goddard': 8,
#              'instead': 1916,
#              'love': 4439,
#              'inflation': 11,
#              'people': 6131,
#              'wall': 308,
#              'plays': 1882,
#              'molly': 68,
#              'monitor': 28,
#              'connection': 236,
#              'been': 6650,
#              'survivors': 86,
#              'up': 8664,
#              'got': 3015,
#              'are': 13898,
#              'having': 2202,
#              'sissy': 45,
#              'bracelet': 7,
#              'an': 12205,
#              'for': 17882,
#              'next': 1511,
#              'meets': 621,
#              'prior': 179,
#              'from': 11712,
#              'you': 12887,
#              'making': 2549,
#              'day': 2217,
#              'but': 17975,
#              'had': 7453,
#              'dancer': 124,
#              'found': 2238,
#              'rich': 515,
#              'before': 3597,
#              'considered': 450,
#              'films': 4599,
#              'without': 2812,
#              'george': 644,
#              'tambor': 8,
#              'being': 5026,
#              'frankenstein': 65,
#              'pressuring': 5,
#              'divorce': 82,
#              'howard': 179,
#              'nickname': 17,
#              'inspire': 62,
#              'plot': 5008,
#              "they're": 1048,
#              'jeffery': 14,
#              'his': 10678,
#              'every': 3297,
#              'ann': 153,
#              'pals': 35,
#              'observant': 13,
#              'treasure': 161,
#              'or': 10336,
#              'kill': 1014,
#              "don't": 6264,
#              'sidewalk': 38,
#              "he's": 2030,
#              'like': 11674,
#              'not': 14933,
#              'mel': 94,
#              "it's": 9221,
#              'directs': 103,
#              'houselessness': 1,
#              'brooks': 86,
#              'if': 10684,
#              'cause': 423,
#              'entertainment': 791,
#              'lost': 1324,
#              'pepto': 3,
#              'this': 22633,
#              'elections': 6,
#              'worrying': 39,
#              'stars': 1463,
#              'already': 1242,
#              'stupid': 1351,
#              'give': 2955,
#              'teddy': 32,
#              'war': 1157,
#              'streets': 222,
#              'bleeds': 6,
#              'scene': 3810,
#              'ever': 4800,
#              'usual': 878,
#              'also': 6457,
#              'boss': 301,
#              'malevolent': 25,
#              'scenes': 3913,
#              'each': 2053,
#              'face': 1408,
#              'clothes': 307,
#              'fantastic': 713,
#              'larry': 134,
#              'millionaire': 66,
#              'best': 4894,
#              'later': 1832,
#              'look': 3443,
#              'lawyers': 28,
#              'warehouse': 34,
#              'indifferently': 3,
#              'words': 813,
#              'good': 9614,
#              'jeffrey': 88,
#              'dishonest': 18,
#              'invade': 12,
#              'take': 2982,
#              'none': 966,
#              'accused': 114,
#              'brilliant': 1026,
#              'seen': 5326,
#              'second': 1709,
#              'legs': 146,
#              'lady': 607,
#              'crush': 97,
#              'selling': 126,
#              'anything': 2555,
#              'over': 4757,
#              'turncoat': 3,
#              'corn': 53,
#              'lawyer': 168,
#              'quite': 3031,
#              'site': 225,
#              'favorite': 1085,
#              'often': 1389,
#              'ghetto': 45,
#              'diggers': 13,
#              'out': 10610,
#              'says': 947,
#              'gets': 2616,
#              'hobo': 8,
#              'demolition': 14,
#              'shrugs': 5,
#              'movie': 15227,
#              'funny': 3128,
#              'mad': 399,
#              'have': 14183,
#              'too': 5721,
#              'classics': 220,
#              'better': 4624,
#              'hospital': 271,
#              'three': 1815,
#              'big': 2791,
#              'superb': 621,
#              'dramatic': 590,
#              'fighting': 507,
#              'acting': 5349,
#              'sanders': 33,
#              'two': 4961,
#              'character': 4671,
#              'reviled': 7,
#              'truly': 1531,
#              'else': 1772,
#              'realistic': 651,
#              'citizen': 104,
#              'gave': 1111,
#              'story': 7580,
#              'does': 4548,
#              'singers': 62,
#              'still': 4429,
#              'pull': 330,
#              'cannon': 60,
#              'society': 534,
#              'jokes': 751,
#              'way': 6030,
#              'members': 486,
#              'complaint': 130,
#              'king': 566,
#              'say': 4336,
#              'either': 1671,
#              'titanic': 79,
#              'so': 11710,
#              'inn': 17,
#              'writer': 969,
#              'easily': 820,
#              'its': 5173,
#              'idiots': 112,
#              'fall': 721,
#              'lovable': 140,
#              'how': 6300,
#              'very': 8664,
#              'traditionally': 20,
#              'only': 8358,
#              'fisher': 69,
#              'flat': 534,
#              'kane': 105,
#              'underrated': 226,
#              'comedies': 371,
#              'impressive': 456,
#              'cast': 3222,
#              'unlike': 555,
#              'director': 3391,
#              'sure': 2374,
#              'lounge': 13,
#              'flawed': 145,
#              'someone': 1917,
#              'italians': 31,
#              'crap': 874,
#              'view': 854,
#              'leslie': 144,
#              'she': 5175,
#              'directly': 188,
#              'cut': 883,
#              'himself': 1800,
#              'actress': 1045,
#              'rent': 664,
#              'both': 2734,
#              'moments': 1433,
#              'well': 7525,
#              'speaking': 385,
#              'was': 16162,
#              'audience': 1766,
#              'under': 1254,
#              'probably': 2437,
#              'less': 1737,
#              'bit': 2564,
#              'actually': 3438,
#              'job': 1913,
#              'actor': 1921,
#              'there': 9725,
#              'rated': 448,
#              'typical': 703,
#              'room': 767,
#              'price': 240,
#              'movies': 5343,
#              'overall': 1320,
#              'again': 3244,
#              'fume': 2,
#              'characteristic': 42,
#              'could': 5863,
#              'followable': 4,
#              'made': 6364,
#              'fleshed': 53,
#              'played': 2118,
#              'parts': 1075,
#              'worth': 2089,
#              'person': 1311,
#              'felt': 1305,
#              '10': 3352,
#              'saturday': 203,
#              'premise': 655,
#              'guy': 2180,
#              'keeper': 36,
#              'close': 1176,
#              'suspense': 639,
#              'se': 43,
#              'rates': 76,
#              'fails': 562,
#              'recent': 481,
#              'night': 1710,
#              'entertained': 226,
#              'thriller': 730,
#              'attempts': 538,
#              'third': 664,
#              'quirky': 168,
#              '7': 830,
#              'mystery': 695,
#              'real': 3703,
#              'report': 89,
#              'oh': 1221,
#              'able': 1142,
#              'mixed': 260,
#              'rory': 21,
#              'hybrid': 51,
#              'watching': 3826,
#              'locate': 34,
#              'vehicle': 217,
#              'news': 292,
#              'sandra': 56,
#              'friday': 173,
#              'fiend': 40,
#              'perspective': 234,
#              'boy': 1155,
#              'nor': 631,
#              'per': 138,
#              "robin's": 6,
#              "william's": 11,
#              'actions': 282,
#              'starring': 463,
#              'robin': 170,
#              'teach': 127,
#              'goal': 132,
#              'new': 3218,
#              'definitely': 1412,
#              'dramatization': 17,
#              'drama': 1180,
#              'comedic': 291,
#              'williams': 220,
#              'subscribe': 11,
#              'guide': 118,
#              'fare': 198,
#              'amuse': 31,
#              'though': 3591,
#              'fame': 216,
#              'performing': 122,
#              'inspect': 7,
#              'achieving': 31,
#              'highly': 1066,
#              'insane': 204,
#              'culkin': 24,
#              'watch': 5463,
#              'sick': 435,
#              'must': 2748,
#              'pretty': 2911,
#              'sexuality': 131,
#              'nice': 1683,
#              'however': 2949,
#              '1': 1774,
#              'notice': 345,
#              'core': 235,
#              'fine': 1159,
#              'enough': 2870,
#              'hear': 677,
#              'affects': 59,
#              'performance': 2274,
#              'looking': 2167,
#              'short': 1551,
#              'back': 3935,
#              'affect': 90,
#              'unexpectedness': 2,
#              'thrilling': 152,
#              'angles': 196,
#              'even': 8413,
#              'engaging': 295,
#              'yes': 1309,
#              'lights': 171,
#              'wondering': 350,
#              'desired': 89,
#              'keep': 1476,
#              'art': 980,
#              'unfolds': 101,
#              'paced': 280,
#              'seem': 1921,
#              'enjoy': 1616,
#              'grips': 32,
#              'rush': 121,
#              'use': 1582,
#              'onto': 306,
#              'slow': 995,
#              'successfully': 158,
#              'direction': 1262,
#              'lay': 89,
#              'volumes': 34,
#              'achieve': 167,
#              "doesn't": 3616,
#              'happening': 358,
#              'unnecessary': 292,
#              'widening': 5,
#              'questions': 408,
#              'consideration': 55,
#              'benefit': 100,
#              'deadly': 178,
#              'sent': 365,
#              'editing': 698,
#              'makes': 3539,
#              'joe': 391,
#              'synopsis': 104,
#              'harrowing': 45,
#              'finally': 1381,
#              'terry': 81,
#              'comments': 696,
#              'otherwise': 648,
#              'set': 2126,
#              'talk': 728,
#              'evokes': 45,
#              "director's": 242,
#              'ending': 1937,
#              'attendants': 7,
#              'possibly': 665,
#              'exceptionally': 85,
#              'returns': 277,
#              "collette's": 5,
#              'belongs': 139,
#              'highway': 55,
#              'really': 7628,
#              'organizations': 12,
#              'noticed': 264,
#              'physical': 286,
#              'characterization': 118,
#              "film's": 850,
#              'deleted': 66,
#              'now': 3715,
#              'sandwich': 16,
#              'ashe': 2,
#              'revelation': 130,
#              'collette': 33,
#              'correct': 214,
#              'certain': 699,
#              'hitchcock': 118,
#              'hall': 181,
#              'morton': 20,
#              'seemed': 1165,
#              'suspenseful': 184,
#              'awards': 205,
#              'slighter': 3,
#              'initially': 168,
#              'lose': 311,
#              'question': 610,
#              'into': 6424,
#              'adoptive': 7,
#              'reach': 228,
#              'certainly': 1304,
#              'host': 125,
#              'critically': 29,
#              'patrick': 157,
#              'dispersion': 1,
#              'blindness': 13,
#              'stettner': 3,
#              'stage': 556,
#              'listener': 22,
#              'several': 1269,
#              'finds': 835,
#              'reading': 639,
#              'armistead': 4,
#              'arise': 26,
#              'couple': 1475,
#              'ms': 261,
#              'stop': 997,
#              'gay': 372,
#              'pete': 48,
#              'due': 843,
#              'nature': 587,
#              'chopped': 56,
#              'drawn': 405,
#              'mr': 955,
#              'logand': 4,
#              'becomes': 1209,
#              'saying': 867,
#              'writers': 587,
#              'celebrated': 57,
#              'might': 2423,
#              'helped': 302,
#              'roles': 1010,
#              'vending': 3,
#              'anderson': 139,
#              'based': 1303,
#              'these': 4107,
#              '06': 10,
#              'believable': 666,
#              'bobby': 91,
#              'creepy': 533,
#              "boy's": 59,
#              'impersonation': 27,
#              'mother': 1020,
#              'gratitude': 21,
#              'true': 1968,
#              "'psycho'": 3,
#              'award': 369,
#              'overkill': 20,
#              'giving': 795,
#              'perfect': 1355,
#              'maupin': 4,
#              'acclaimed': 75,
#              'machine': 253,
#              'hides': 63,
#              'obvious': 982,
#              'according': 286,
#              'secret\x85': 1,
#              'strong': 959,
#              'relationship': 799,
#              'getting': 1431,
#              'land': 311,
#              'mental': 275,
#              'would': 8043,
#              'cannavale': 9,
#              'planning': 120,
#              'late': 1096,
#              'deserve': 275,
#              'donna': 69,
#              'everywhere': 188,
#              '21': 59,
#              'anna': 132,
#              'exemplary': 15,
#              'troubling': 18,
#              'captivated': 44,
#              'jess': 45,
#              'york': 603,
#              'offers': 328,
#              'ailments': 6,
#              'establishing': 52,
#              'toni': 44,
#              'events': 767,
#              'women': 1250,
#              'psychological': 231,
#              're': 685,
#              'gabriel': 46,
#              'video': 1370,
#              'tape': 207,
#              'official': 99,
#              'inner': 193,
#              'novice': 26,
#              'aids': 65,
#              'emery': 6,
#              'helps': 344,
#              'truths': 48,
#              'sudden': 217,
#              'discovering': 74,
#              'nurse': 100,
#              'disturbed': 100,
#              'lover': 331,
#              'conflicted': 37,
#              'nightmarish': 47,
#              'decides': 500,
#              'travails': 7,
#              'backgrounds': 100,
#              'latest': 192,
#              'desperation': 97,
#              'suddenly': 489,
#              'youth': 245,
#              'interesting': 2620,
#              'ulterior': 12,
#              'near': 773,
#              'tilt': 15,
#              'abducted': 29,
#              'teacup': 4,
#              'dreadful': 224,
#              'former': 465,
#              'reads': 90,
#              'no': 8201,
#              'apartment': 261,
#              'adopted': 68,
#              '2': 2248,
#              'hoax': 12,
#              'run': 1088,
#              'low': 1531,
#              'dir': 29,
#              'motives': 97,
#              'airwaves': 10,
#              'radio': 243,
#              'thing': 3725,
#              'escaped': 102,
#              'tailspin': 3,
#              'excellent': 1774,
#              'voice': 878,
#              'repetitive': 114,
#              'gives': 1419,
#              'form': 705,
#              'eventually': 663,
#              'stand': 749,
#              'fashioned': 133,
#              'suspenser': 3,
#              'investigating': 70,
#              'becky': 11,
#              'co': 533,
#              'any': 5770,
#              '2006': 138,
#              'derange': 2,
#              'paranoia': 79,
#              'norm': 63,
#              'naturally': 258,
#              "fan's": 9,
#              'pot': 92,
#              'whose': 850,
#              'rattle': 9,
#              'screenplay': 622,
#              'ultimately': 489,
#              'gas': 149,
#              'predictable': 773,
#              'him': 5119,
#              'john': 1572,
#              'submitted': 23,
#              'troubled': 138,
#              'fact': 2969,
#              "didn't": 3432,
#              "pete's": 13,
#              'baker': 103,
#              'devious': 29,
#              'piece': 1372,
#              'scenario': 168,
#              'own': 2756,
#              'finely': 38,
#              'why': 3872,
#              'departure': 64,
#              'accumulated': 7,
#              'intrigued': 116,
#              'unmentioned': 4,
#              'existence': 248,
#              'grown': 235,
#              'hope': 1300,
#              'dying': 279,
#              'hitchcockian': 16,
#              'pays': 104,
#              'rescued': 57,
#              'doubt': 708,
#              'trait': 26,
#              'penned': 45,
#              'emotional': 582,
#              'stories': 900,
#              'associates': 33,
#              'personality': 315,
#              'reveals': 175,
#              'underlines': 12,
#              'directed': 1112,
#              'cullum': 2,
#              'named': 674,
#              'planted': 33,
#              'read': 1607,
#              'wrote': 532,
#              'boiler': 12,
#              'genuinely': 239,
#              'editor': 103,
#              'estranged': 58,
#              'abused': 71,
#              'meet': 597,
#              'lisa': 106,
#              'correspondence': 9,
#              'unsettling': 92,
#              'careful': 86,
#              'celebrities': 39,
#              'sexually': 122,
#              'hearted': 219,
#              'anticipate': 17,
#              'city': 864,
#              'leave': 1002,
#              'key': 386,
#              'number': 831,
#              'tempest': 21,
#              'hoodwink': 2,
#              'runs': 481,
#              "one's": 230,
#              'almost': 2657,
#              'full': 1567,
#              'manuscript': 15,
#              'seed': 45,
#              'old': 3463,
#              'fans': 1182,
#              'listen': 317,
#              'fan': 1653,
#              'despite': 1208,
#              'done': 2654,
#              'contracted': 11,
#              'actresses': 331,
#              '2008': 70,
#              'release': 686,
#              'feeling': 1026,
#              'academy': 253,
#              'exist': 278,
#              'lately': 92,
#              'online': 80,
#              'smoochy': 3,
#              'cry': 345,
#              'anyone': 2281,
#              'leaves': 642,
#              'takes': 1937,
#              'killer': 908,
#              'reports': 54,
#              'reviews': 631,
#              'understated': 87,
#              'quick': 317,
#              'resurfaced': 3,
#              'cult': 400,
#              'scary': 762,
#              'bombed': 37,
#              'dangerous': 262,
#              'autobiography': 37,
#              'camera': 1459,
#              'came': 1535,
#              'case': 1333,
#              'decade': 231,
#              'strange': 797,
#              'horrific': 156,
#              'photo': 78,
#              'mind': 1792,
#              'sort': 1274,
#              'feelings': 354,
#              'incredible': 496,
#              'portrayed': 552,
#              'result': 602,
#              'dark': 1125,
#              'concept': 476,
#              'bless': 40,
#              'child': 961,
#              'godby': 1,
#              'least': 2718,
#              'unsettled': 9,
#              'thought': 2915,
#              'constantly': 391,
#              'sociopathic': 8,
#              'caretaker': 37,
#              'confused': 357,
#              'play': 1728,
#              'nominated': 176,
#              'insomnia': 50,
#              'confirmed': 38,
#              'hour': 1040,
#              'suffered': 145,
#              'exception': 392,
#              'looked': 905,
#              'sunshine': 75,
#              'god': 851,
#              'dramas': 129,
#              'period': 687,
#              'staring': 93,
#              'perhaps': 1455,
#              'especially': 2268,
#              'officially': 40,
#              'miss': 765,
#              'reviewed': 52,
#              'actual': 707,
#              'may': 2681,
#              'because': 6248,
#              'fraud': 43,
#              'shooting': 419,
#              'role': 2455,
#              'johnson': 134,
#              'generation': 217,
#              'recommend': 1594,
#              'dvd': 1867,
#              'mediocre': 346,
#              'among': 720,
#              'little': 4835,
#              'moved': 302,
#              'times': 2792,
#              'yet': 2266,
#              'dumb': 501,
#              'serial': 284,
#              'abuse': 172,
#              'prepared': 168,
#              'brilliantly': 235,
#              'death': 1511,
#              'physically': 146,
#              'include': 357,
#              'anthony': 218,
#              'chilling': 155,
#              'foot': 213,
#              'review': 746,
#              'irrevocably': 3,
#              'expected': 664,
#              'book': 1431,
#              'maupins': 1,
#              'our': 1851,
#              'succeeded': 103,
#              'turns': 1145,
#              'please': 887,
#              'find': 3383,
#              'go': 4186,
#              'cares': 221,
#              'chance': 968,
#              'screen': 2100,
#              'changing': 182,
#              'captures': 203,
#              'seems': 2902,
#              "1940's": 32,
#              'amount': 465,
#              'gloss': 20,
#              'displayed': 97,
#              'personnel': 26,
#              'forward': 629,
#              'trust': 307,
#              'lets': 317,
#              'bad': 5886,
#              'american': 1653,
#              'leading': 572,
#              'lives': 1195,
#              'ourselves': 138,
#              'reminded': 329,
#              'nothing': 3427,
#              'essence': 133,
#              'strength': 231,
#              'within': 753,
#              'version': 1430,
#              'hacks': 24,
#              'hollywood': 1447,
#              'opinion': 872,
#              'change': 868,
#              'us': 2757,
#              'carry': 307,
#              'event': 321,
#              's': 759,
#              'loves': 372,
#              'taken': 932,
#              'players': 259,
#              'forget': 670,
#              'presence': 386,
#              'first': 6418,
#              'introduced': 289,
#              'smallest': 31,
#              'looks': 1998,
#              'serious': 896,
#              'struggle': 279,
#              'average': 649,
#              'restraint': 41,
#              'steals': 208,
#              'issues': 354,
#              ...})

# %%
train_sequences=token.texts_to_sequences(train_texts)
test_sequences=token.texts_to_sequences(test_texts)

# %%
print(train_texts[0])
# Out:
# Bromwell High is a cartoon comedy. It ran at the same time as some other programs about school life, such as "Teachers". My 35 years in the teaching profession lead me to believe that Bromwell High's satire is much closer to reality than is "Teachers". The scramble to survive financially, the insightful students who can see right through their pathetic teachers' pomp, the pettiness of the whole situation, all remind me of the schools I knew and their students. When I saw the episode in which a student repeatedly tried to burn down the school, I immediately recalled ......... at .......... High. A classic line: INSPECTOR: I'm here to sack one of your teachers. STUDENT: Welcome to Bromwell High. I expect that many adults of my age think that Bromwell High is far fetched. What a pity that it isn't!

# %%
print(train_sequences[0])
# Out:
# [308, 6, 3, 1068, 208, 8, 2160, 29, 1, 168, 54, 13, 45, 81, 40, 391, 109, 137, 13, 57, 149, 7, 1, 481, 68, 5, 260, 11, 2000, 6, 72, 2422, 5, 631, 70, 6, 1, 5, 2001, 1, 1530, 33, 66, 63, 204, 139, 64, 1229, 1, 4, 1, 222, 899, 28, 3021, 68, 4, 1, 9, 693, 2, 64, 1530, 50, 9, 215, 1, 386, 7, 59, 3, 1470, 3710, 798, 5, 3509, 176, 1, 391, 9, 1235, 29, 308, 3, 352, 343, 2970, 142, 129, 5, 27, 4, 125, 1470, 2372, 5, 308, 9, 532, 11, 107, 1466, 4, 57, 554, 100, 11, 308, 6, 226, 47, 3, 2231, 11, 8, 214]

# %% [markdown]
# # 让转换后数字列表长度相同

# %%
x_train=tf.keras.preprocessing.sequence.pad_sequences(train_sequences,padding='post',truncating='post',maxlen=400)
x_test=tf.keras.preprocessing.sequence.pad_sequences(test_sequences,padding='post',truncating='post',maxlen=400)
y_train=np.array(train_labels)
y_test=np.array(test_labels)

# %%
x_train.shape
# Out:
# (25000, 400)

# %% [markdown]
# # 建立模型

# %%
model=tf.keras.models.Sequential()

# %%
model.add(tf.keras.layers.Embedding(output_dim=32,
                                   input_dim=4000,
                                   input_length=400))
# Out:
# WARNING:tensorflow:From E:\anaconda\anaconda\envs\TensorFlow\lib\site-packages\tensorflow\python\keras\initializers.py:119: calling RandomUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
# 用RNN牛拍卖行把词嵌入平坦化
# model.add(keras.layers.SimpleRNN(units=16))
model.add(tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(units=8)))
# 双相LSTM
# Out:
# WARNING:tensorflow:From E:\anaconda\anaconda\envs\TensorFlow\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From E:\anaconda\anaconda\envs\TensorFlow\lib\site-packages\tensorflow\python\ops\init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From E:\anaconda\anaconda\envs\TensorFlow\lib\site-packages\tensorflow\python\ops\init_ops.py:97: calling Orthogonal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From E:\anaconda\anaconda\envs\TensorFlow\lib\site-packages\tensorflow\python\ops\init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
model.add(tf.keras.layers.Dense(units=32,activation='relu'))

# %%
model.add(tf.keras.layers.Dropout(0.3))

# %%
model.add(tf.keras.layers.Dense(units=2,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 400, 32)           128000
# _________________________________________________________________
# bidirectional (Bidirectional (None, 16)                2624
# _________________________________________________________________
# dense (Dense)                (None, 32)                544
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 66
# =================================================================
# Total params: 131,234
# Trainable params: 131,234
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 训练模型

# %%
model.compile(optimizer='adam',
             loss='categorical_crossentropy',
             metrics=['accuracy'])

# %%
history=model.fit(x_train,y_train,
                 validation_split=0.2,
                 epochs=10,
                 batch_size=128,
                 verbose=1)
# Out:
# Train on 20000 samples, validate on 5000 samples
# WARNING:tensorflow:From E:\anaconda\anaconda\envs\TensorFlow\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/10
# 20000/20000 [==============================] - 42s 2ms/sample - loss: 0.5820 - acc: 0.6854 - val_loss: 0.4002 - val_acc: 0.8732
# Epoch 2/10
# 20000/20000 [==============================] - 46s 2ms/sample - loss: 0.3456 - acc: 0.8636 - val_loss: 0.3613 - val_acc: 0.8650
# Epoch 3/10
# 20000/20000 [==============================] - 49s 2ms/sample - loss: 0.3066 - acc: 0.8850 - val_loss: 0.5438 - val_acc: 0.7932
# Epoch 4/10
# 20000/20000 [==============================] - 52s 3ms/sample - loss: 0.2604 - acc: 0.9062 - val_loss: 0.6100 - val_acc: 0.7630
# Epoch 5/10
# 20000/20000 [==============================] - 57s 3ms/sample - loss: 0.2328 - acc: 0.9196 - val_loss: 0.3254 - val_acc: 0.8744
# Epoch 6/10
# 20000/20000 [==============================] - 60s 3ms/sample - loss: 0.2170 - acc: 0.9244 - val_loss: 0.3469 - val_acc: 0.8664
# Epoch 7/10
# 20000/20000 [==============================] - 68s 3ms/sample - loss: 0.1893 - acc: 0.9364 - val_loss: 0.5498 - val_acc: 0.8084
# Epoch 8/10
# 20000/20000 [==============================] - 79s 4ms/sample - loss: 0.1759 - acc: 0.9421 - val_loss: 0.3272 - val_acc: 0.8854
# Epoch 9/10
# 20000/20000 [==============================] - 90s 4ms/sample - loss: 0.1615 - acc: 0.9487 - val_loss: 0.4664 - val_acc: 0.8432
# Epoch 10/10
# 15488/20000 [======================>.......] - ETA: 21s - loss: 0.1386 - acc: 0.9576

# %% [markdown]
# # 可视化

# %% [markdown]
# # 评估准确率

# %%
test_loss,test_acc=model.evaluate(x_test,y_test,verbose=1)
print('Test Accuracy',test_acc)

# %% [markdown]
# # 执行预测

# %%
predictions=model.predict(x_test)
predictions[0]

# %% [markdown]
# # 查看数据的预测结果

# %%
sentiment_dict={0:'pos',1:'neg'}
def display_test_sentiment(i):
    print(test_texts[i])
    print('label values',sentiment_dict[np.argmax(y_test[i])],
          'predict value:',sentiment_dict[np.argmax()]

# %%
display_test_sentiment(0)

# %% [markdown]
# 网上找评论来试验
