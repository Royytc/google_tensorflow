# %%
# 导入需要用的库
import os
import tarfile
# 软件包的解压
import urllib.request
#网络下载的请求
import tensorflow as tf
import numpy as np

import re
# 正则化
import string

from random import randint

# %%
# 数据地址
url='http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz'
filepath='data/aclImdb_v1.tar.gz'

# %%
# 如果当前目录下不存在data文件夹，则建立
if not os.path.exists('data'):
    os.makedirs('data')
# 下载数据，80兆左右
if not os.path.isfile(filepath):
    print('downloading...')
    result=urllib.request.urlretrieve(url,filepath)
    print('downloaded:',result)
else:
    print(filepath,'is existed')
# Out:
# data/aclImdb_v1.tar.gz is existed

# %%
# 解压数据
if not os.path.exists('data/aclImdb'):
    tfile=tarfile.open(filepath,'r:gz')
    print('extracting...')
    result=tfile.extractall('data/')
    print('extraction completed')
else:
    print('data/aclImdb is existed!')
# Out:
# data/aclImdb is existed!

# %%
# 将文本中不需要的字符清除，如html中的标签<br />
def remove_tags(text):
    re_tag=re.compile(r'<[^>]+>')
    return re_tag.sub('',text)

# %%
def read_files(filetype):
    path='data/aclImdb/'
    file_list=[]
    # 读取正面评价的文件路径，存到file_list列表里
    positive_path=path+filetype+'/pos/'
    for f in os.listdir(positive_path):
        file_list+=[positive_path+f]
    pos_files_num=len(file_list)
    # 读取负面评价的文件的路径，存到file_list列表里
    negative_path=path+filetype+'/neg/'
    for  f in os.listdir(negative_path):
        file_list+=[negative_path+f]
    neg_files_num=len(file_list)-pos_files_num
    
    print('read',filetype,'files:',len(file_list))
    print(pos_files_num,'pos files in',filetype,'files')
    print(neg_files_num,'neg files in',filetype,'files')
    #得到所有标签。标签用one——hot编码，正面{1,0}负面[0,1]
    all_labels=([[1,0]]*pos_files_num+[[0,1]]*neg_files_num)
    
    # 得到所有文本
    all_texts=[]
    for fi in file_list:
        with open(fi,encoding='utf8') as file_input:
            #文本中有<br />这类html标签，将文本传入remove_tags函数
            #函数里用正则表达式将标签去除
            all_texts+=[remove_tags(''.join(file_input.readlines()))]
    return all_labels,all_texts

# %%
train_labels,train_texts=read_files("train")
test_labels,test_texts=read_files('test')
# Out:
# read train files: 25000
# 12500 pos files in train files
# 12500 neg files in train files
# read test files: 25000
# 12500 pos files in test files
# 12500 neg files in test files

# %% [markdown]
# # 建立词汇词典 Token

# %%
token=tf.keras.preprocessing.text.Tokenizer(num_words=4000)
# 分词器，把出现率最高的4000个词纳入分词器

# %%
token.fit_on_texts(train_texts)

# %%
# 查看token读取了多少文档
token.document_count
# Out:
# 25000

# %%
#print(token.word_index)# 出现频率的排名

# %%
token.word_docs
# 将单词映射为他们在训练器出现的文档或文本的数量
# Out:
# defaultdict(int,
#             {'remind': 152,
#              'of': 23726,
#              'student': 322,
#              'down': 3092,
#              'than': 7117,
#              'bromwell': 4,
#              'situation': 600,
#              'believe': 2209,
#              'far': 2551,
#              'survive': 239,
#              'see': 8080,
#              'much': 7084,
#              'knew': 822,
#              'whole': 2641,
#              'repeatedly': 117,
#              'fetched': 98,
#              'at': 12936,
#              'what': 9634,
#              'teaching': 78,
#              'saw': 2756,
#              'their': 6982,
#              'lead': 1170,
#              'about': 10490,
#              'in': 22036,
#              'as': 16116,
#              'my': 8106,
#              'immediately': 434,
#              'insightful': 63,
#              'through': 3992,
#              '35': 94,
#              'adults': 330,
#              'schools': 56,
#              'episode': 984,
#              'cartoon': 367,
#              'think': 5440,
#              'classic': 1543,
#              'some': 9644,
#              'pomp': 8,
#              'welcome': 204,
#              'your': 4266,
#              'line': 1613,
#              'such': 4022,
#              'to': 23474,
#              'it': 21332,
#              'many': 5067,
#              "high's": 1,
#              'tried': 704,
#              'burn': 125,
#              'closer': 190,
#              'here': 4199,
#              'me': 7329,
#              'that': 20039,
#              'reality': 793,
#              'can': 7851,
#              "teachers'": 1,
#              'right': 2772,
#              'expect': 1066,
#              'other': 6679,
#              'same': 3323,
#              'is': 22425,
#              'a': 24173,
#              "isn't": 2587,
#              'pathetic': 431,
#              'the': 24792,
#              'years': 3638,
#              'which': 7572,
#              'one': 14096,
#              'teachers': 64,
#              'i': 19225,
#              'age': 966,
#              'programs': 62,
#              'and': 24161,
#              'profession': 61,
#              'who': 11132,
#              'pity': 225,
#              'school': 1240,
#              'satire': 209,
#              'recalled': 18,
#              'comedy': 2337,
#              'sack': 42,
#              'scramble': 6,
#              'all': 13069,
#              'pettiness': 2,
#              'financially': 28,
#              'life': 4576,
#              'students': 276,
#              'inspector': 110,
#              'when': 9027,
#              'high': 1837,
#              'time': 8719,
#              'ran': 225,
#              "i'm": 3655,
#              'after': 5780,
#              'written': 1462,
#              'dancer': 124,
#              'know': 4774,
#              'between': 2744,
#              'fumes': 4,
#              'where': 4730,
#              "bet's": 2,
#              'entertainment': 791,
#              'until': 1615,
#              'survivors': 86,
#              'streets': 222,
#              'slapstick': 157,
#              'once': 2079,
#              'ex': 405,
#              'step': 310,
#              'used': 1656,
#              'frankenstein': 65,
#              'valuable': 88,
#              'jeffery': 14,
#              'kids': 1249,
#              'blazing': 42,
#              'man': 3790,
#              'he': 9899,
#              'goddard': 8,
#              'on': 15710,
#              'wall': 308,
#              'do': 6639,
#              'help': 1623,
#              'if': 10684,
#              'sailor': 39,
#              'shows': 1913,
#              'pepto': 3,
#              'wants': 1124,
#              'howard': 179,
#              'prior': 179,
#              'but': 17975,
#              'from': 11712,
#              'racism': 118,
#              'by': 11719,
#              'tambor': 8,
#              'day': 2217,
#              'without': 2812,
#              "they're": 1048,
#              'teddy': 32,
#              'make': 6127,
#              'treasure': 161,
#              'rich': 515,
#              'fight': 903,
#              'necessary': 309,
#              'money': 1955,
#              'future': 757,
#              'divorce': 82,
#              'george': 644,
#              'world': 2784,
#              'live': 1349,
#              'show': 3333,
#              'sissy': 45,
#              'lesley': 12,
#              'lesson': 230,
#              'people': 6131,
#              'reaching': 92,
#              'going': 3380,
#              'thrown': 388,
#              'you': 12887,
#              'mel': 94,
#              'human': 1264,
#              'plan': 381,
#              "don't": 6264,
#              'using': 731,
#              'everything': 2019,
#              'had': 7453,
#              'buildings': 90,
#              'compared': 516,
#              'work': 3515,
#              'month': 135,
#              'having': 2202,
#              'his': 10678,
#              'mutual': 61,
#              "brooks'": 17,
#              'vote': 212,
#              'film': 13822,
#              'war': 1157,
#              'were': 6771,
#              'love': 4439,
#              'give': 2955,
#              'forehead': 23,
#              'stupid': 1351,
#              'vagrant': 3,
#              'monopoly': 9,
#              'did': 4747,
#              "they'll": 118,
#              'like': 11674,
#              'rival': 144,
#              'wilson': 141,
#              'pictures': 394,
#              'given': 1630,
#              'move': 672,
#              'meets': 621,
#              "bolt's": 1,
#              'stated': 128,
#              'should': 4037,
#              'lost': 1324,
#              'bathroom': 103,
#              'considered': 450,
#              'days': 1153,
#              "he's": 2030,
#              'has': 10063,
#              'woman': 2008,
#              'plays': 1882,
#              'most': 6509,
#              'matter': 1037,
#              'this': 22633,
#              'bolt': 16,
#              'those': 3769,
#              'succeed': 145,
#              'worrying': 39,
#              'deciding': 52,
#              'never': 5015,
#              'with': 17462,
#              "it's": 9221,
#              'molly': 68,
#              'will': 6244,
#              'homeless': 92,
#              'every': 3297,
#              'nickname': 17,
#              'stinks': 91,
#              'iraq': 66,
#              'young': 2708,
#              'kill': 1014,
#              'luxuries': 3,
#              'thirty': 133,
#              'before': 3597,
#              'technology': 197,
#              'things': 2995,
#              'maybe': 1976,
#              'carlin': 10,
#              'homelessness': 7,
#              'connection': 236,
#              'they': 10362,
#              'just': 10545,
#              'inflation': 11,
#              'killed': 916,
#              'be': 14135,
#              'brooks': 86,
#              'bet': 220,
#              'characters': 5035,
#              'her': 6456,
#              'found': 2238,
#              'agreements': 4,
#              'films': 4599,
#              'side': 1102,
#              'something': 4061,
#              'morris': 58,
#              'sidewalk': 38,
#              'tender': 96,
#              'name': 1386,
#              'ann': 153,
#              'got': 3015,
#              'an': 12205,
#              'pressuring': 5,
#              'computer': 355,
#              'home': 1533,
#              'others': 1434,
#              'including': 967,
#              'project': 439,
#              'hand': 1088,
#              'not': 14933,
#              'stars': 1463,
#              'monitor': 28,
#              'pals': 35,
#              'losing': 206,
#              'issue': 253,
#              'while': 4091,
#              'observant': 13,
#              'succeeds': 160,
#              'more': 9063,
#              'leg': 87,
#              'flight': 136,
#              'directs': 103,
#              'cause': 423,
#              'elections': 6,
#              'plot': 5008,
#              'inspire': 62,
#              "can't": 3017,
#              'for': 17882,
#              'street': 558,
#              "wasn't": 1927,
#              'saddles': 19,
#              'been': 6650,
#              'up': 8664,
#              'houselessness': 1,
#              'warren': 95,
#              'being': 5026,
#              'instead': 1916,
#              'bracelet': 7,
#              'sets': 792,
#              'making': 2549,
#              'end': 4536,
#              'off': 4635,
#              'spaceballs': 10,
#              'are': 13898,
#              'next': 1511,
#              'already': 1242,
#              'or': 10336,
#              'also': 6457,
#              'face': 1408,
#              'seen': 5326,
#              'fantastic': 713,
#              'funny': 3128,
#              'clothes': 307,
#              'good': 9614,
#              'indifferently': 3,
#              'diggers': 13,
#              'hobo': 8,
#              'boss': 301,
#              'better': 4624,
#              'superb': 621,
#              'millionaire': 66,
#              'warehouse': 34,
#              'usual': 878,
#              'scenes': 3913,
#              'often': 1389,
#              'hospital': 271,
#              'gets': 2616,
#              'scene': 3810,
#              'crush': 97,
#              'ever': 4800,
#              'quite': 3031,
#              'big': 2791,
#              'demolition': 14,
#              'words': 813,
#              'favorite': 1085,
#              'selling': 126,
#              'movie': 15227,
#              'three': 1815,
#              'malevolent': 25,
#              'lawyers': 28,
#              'ghetto': 45,
#              'lawyer': 168,
#              'take': 2982,
#              'dramatic': 590,
#              'bleeds': 6,
#              'invade': 12,
#              'site': 225,
#              'dishonest': 18,
#              'sanders': 33,
#              'says': 947,
#              'too': 5721,
#              'lady': 607,
#              'legs': 146,
#              'second': 1709,
#              'character': 4671,
#              'acting': 5349,
#              'over': 4757,
#              'fighting': 507,
#              'classics': 220,
#              'each': 2053,
#              'out': 10610,
#              'look': 3443,
#              'brilliant': 1026,
#              'larry': 134,
#              'accused': 114,
#              'mad': 399,
#              'corn': 53,
#              'turncoat': 3,
#              'have': 14183,
#              'anything': 2555,
#              'later': 1832,
#              'jeffrey': 88,
#              'best': 4894,
#              'none': 966,
#              'two': 4961,
#              'shrugs': 5,
#              'its': 5173,
#              'underrated': 226,
#              'cast': 3222,
#              'unlike': 555,
#              'how': 6300,
#              'members': 486,
#              'flat': 534,
#              'easily': 820,
#              'very': 8664,
#              'king': 566,
#              'only': 8358,
#              'jokes': 751,
#              'director': 3391,
#              'view': 854,
#              'kane': 105,
#              'writer': 969,
#              'truly': 1531,
#              'does': 4548,
#              'fall': 721,
#              'still': 4429,
#              'so': 11710,
#              'lounge': 13,
#              'lovable': 140,
#              'society': 534,
#              'fisher': 69,
#              'someone': 1917,
#              'else': 1772,
#              'traditionally': 20,
#              'story': 7580,
#              'complaint': 130,
#              'sure': 2374,
#              'gave': 1111,
#              'idiots': 112,
#              'titanic': 79,
#              'singers': 62,
#              'say': 4336,
#              'pull': 330,
#              'impressive': 456,
#              'cannon': 60,
#              'crap': 874,
#              'inn': 17,
#              'comedies': 371,
#              'either': 1671,
#              'reviled': 7,
#              'realistic': 651,
#              'citizen': 104,
#              'italians': 31,
#              'way': 6030,
#              'flawed': 145,
#              'overall': 1320,
#              'played': 2118,
#              'could': 5863,
#              'again': 3244,
#              'rated': 448,
#              'bit': 2564,
#              'actor': 1921,
#              'fume': 2,
#              'she': 5175,
#              'fleshed': 53,
#              'himself': 1800,
#              'price': 240,
#              'well': 7525,
#              'was': 16162,
#              'made': 6364,
#              'under': 1254,
#              'moments': 1433,
#              'movies': 5343,
#              'actually': 3438,
#              'followable': 4,
#              'job': 1913,
#              'worth': 2089,
#              'cut': 883,
#              'both': 2734,
#              'actress': 1045,
#              'leslie': 144,
#              'parts': 1075,
#              'probably': 2437,
#              'room': 767,
#              'characteristic': 42,
#              'less': 1737,
#              'directly': 188,
#              'typical': 703,
#              'audience': 1766,
#              'rent': 664,
#              'speaking': 385,
#              'there': 9725,
#              'boy': 1155,
#              'dramatization': 17,
#              'recent': 481,
#              'subscribe': 11,
#              'starring': 463,
#              'insane': 204,
#              'goal': 132,
#              'amuse': 31,
#              'third': 664,
#              'locate': 34,
#              'entertained': 226,
#              'guide': 118,
#              'attempts': 538,
#              'suspense': 639,
#              'definitely': 1412,
#              'though': 3591,
#              "william's": 11,
#              'vehicle': 217,
#              'perspective': 234,
#              '7': 830,
#              'premise': 655,
#              'robin': 170,
#              'rates': 76,
#              'keeper': 36,
#              'per': 138,
#              'mystery': 695,
#              'hybrid': 51,
#              'mixed': 260,
#              'news': 292,
#              'close': 1176,
#              "robin's": 6,
#              'teach': 127,
#              '10': 3352,
#              'quirky': 168,
#              'fails': 562,
#              'performing': 122,
#              'night': 1710,
#              'culkin': 24,
#              'nor': 631,
#              'pretty': 2911,
#              'fame': 216,
#              'guy': 2180,
#              'inspect': 7,
#              'able': 1142,
#              'saturday': 203,
#              'felt': 1305,
#              'williams': 220,
#              'real': 3703,
#              'friday': 173,
#              'highly': 1066,
#              'must': 2748,
#              'new': 3218,
#              'thriller': 730,
#              'se': 43,
#              'achieving': 31,
#              'sick': 435,
#              'rory': 21,
#              'watching': 3826,
#              'person': 1311,
#              'report': 89,
#              'actions': 282,
#              'drama': 1180,
#              'fiend': 40,
#              'watch': 5463,
#              'fare': 198,
#              'sandra': 56,
#              'oh': 1221,
#              'comedic': 291,
#              'unnecessary': 292,
#              'wondering': 350,
#              'achieve': 167,
#              'paced': 280,
#              'lay': 89,
#              'even': 8413,
#              'happening': 358,
#              "doesn't": 3616,
#              'notice': 345,
#              'short': 1551,
#              'successfully': 158,
#              'desired': 89,
#              'grips': 32,
#              'thrilling': 152,
#              'art': 980,
#              'looking': 2167,
#              'volumes': 34,
#              'onto': 306,
#              'yes': 1309,
#              'rush': 121,
#              'nice': 1683,
#              'affect': 90,
#              'enough': 2870,
#              'however': 2949,
#              'fine': 1159,
#              'angles': 196,
#              'unexpectedness': 2,
#              'core': 235,
#              'back': 3935,
#              'use': 1582,
#              'unfolds': 101,
#              'enjoy': 1616,
#              'lights': 171,
#              'engaging': 295,
#              'hear': 677,
#              'keep': 1476,
#              'sexuality': 131,
#              'direction': 1262,
#              '1': 1774,
#              'seem': 1921,
#              'affects': 59,
#              'slow': 995,
#              'performance': 2274,
#              'might': 2423,
#              '06': 10,
#              'finally': 1381,
#              'bobby': 91,
#              'reading': 639,
#              'otherwise': 648,
#              'offers': 328,
#              'according': 286,
#              "film's": 850,
#              'possibly': 665,
#              'helped': 302,
#              'widening': 5,
#              'exceptionally': 85,
#              'everywhere': 188,
#              'drawn': 405,
#              '21': 59,
#              'into': 6424,
#              'troubling': 18,
#              'question': 610,
#              'patrick': 157,
#              'stettner': 3,
#              "director's": 242,
#              'suspenseful': 184,
#              'set': 2126,
#              'getting': 1431,
#              'certain': 699,
#              'perfect': 1355,
#              'vending': 3,
#              'lose': 311,
#              'stage': 556,
#              'ms': 261,
#              'morton': 20,
#              'would': 8043,
#              'anderson': 139,
#              'deleted': 66,
#              'exemplary': 15,
#              'toni': 44,
#              'psychological': 231,
#              'editing': 698,
#              'relationship': 799,
#              'gay': 372,
#              'obvious': 982,
#              'jess': 45,
#              'makes': 3539,
#              'characterization': 118,
#              'cannavale': 9,
#              'organizations': 12,
#              'reach': 228,
#              "collette's": 5,
#              'gabriel': 46,
#              'video': 1370,
#              'revelation': 130,
#              'awards': 205,
#              'critically': 29,
#              'creepy': 533,
#              'highway': 55,
#              'armistead': 4,
#              'these': 4107,
#              'questions': 408,
#              'establishing': 52,
#              'mental': 275,
#              'tape': 207,
#              'comments': 696,
#              'machine': 253,
#              'sandwich': 16,
#              'maupin': 4,
#              'finds': 835,
#              'award': 369,
#              'ending': 1937,
#              'gratitude': 21,
#              'events': 767,
#              'logand': 4,
#              'terry': 81,
#              'giving': 795,
#              'initially': 168,
#              'several': 1269,
#              'official': 99,
#              'anna': 132,
#              "'psycho'": 3,
#              'pete': 48,
#              'secret\x85': 1,
#              'overkill': 20,
#              'due': 843,
#              'deserve': 275,
#              'couple': 1475,
#              'benefit': 100,
#              'becomes': 1209,
#              'attendants': 7,
#              "boy's": 59,
#              'host': 125,
#              'joe': 391,
#              'dispersion': 1,
#              'ashe': 2,
#              'adoptive': 7,
#              'york': 603,
#              'donna': 69,
#              'planning': 120,
#              'hall': 181,
#              'late': 1096,
#              'mother': 1020,
#              'believable': 666,
#              'arise': 26,
#              'sent': 365,
#              'true': 1968,
#              'deadly': 178,
#              'acclaimed': 75,
#              'women': 1250,
#              'blindness': 13,
#              'celebrated': 57,
#              'nature': 587,
#              'physical': 286,
#              'mr': 955,
#              're': 685,
#              'hitchcock': 118,
#              'really': 7628,
#              'collette': 33,
#              'now': 3715,
#              'strong': 959,
#              'harrowing': 45,
#              'roles': 1010,
#              'certainly': 1304,
#              'noticed': 264,
#              'synopsis': 104,
#              'evokes': 45,
#              'chopped': 56,
#              'impersonation': 27,
#              'returns': 277,
#              'talk': 728,
#              'seemed': 1165,
#              'slighter': 3,
#              'consideration': 55,
#              'correct': 214,
#              'land': 311,
#              'listener': 22,
#              'saying': 867,
#              'stop': 997,
#              'based': 1303,
#              'hides': 63,
#              'captivated': 44,
#              'ailments': 6,
#              'belongs': 139,
#              'writers': 587,
#              'why': 3872,
#              'tilt': 15,
#              'finely': 38,
#              'fact': 2969,
#              'devious': 29,
#              'discovering': 74,
#              'runs': 481,
#              'emery': 6,
#              'lisa': 106,
#              'full': 1567,
#              'suspenser': 3,
#              'almost': 2657,
#              'scenario': 168,
#              'submitted': 23,
#              'dying': 279,
#              'nurse': 100,
#              'rattle': 9,
#              'personality': 315,
#              'piece': 1372,
#              'norm': 63,
#              'excellent': 1774,
#              'radio': 243,
#              'despite': 1208,
#              '2': 2248,
#              'manuscript': 15,
#              'desperation': 97,
#              'intrigued': 116,
#              'grown': 235,
#              'gives': 1419,
#              'eventually': 663,
#              'careful': 86,
#              'helps': 344,
#              'co': 533,
#              'leave': 1002,
#              'screenplay': 622,
#              'dir': 29,
#              'reads': 90,
#              'any': 5770,
#              'named': 674,
#              'tailspin': 3,
#              'escaped': 102,
#              'sexually': 122,
#              'number': 831,
#              'tempest': 21,
#              'travails': 7,
#              "pete's": 13,
#              'hearted': 219,
#              'near': 773,
#              'ultimately': 489,
#              'troubled': 138,
#              'genuinely': 239,
#              'youth': 245,
#              'abducted': 29,
#              'ulterior': 12,
#              'stories': 900,
#              'naturally': 258,
#              'pays': 104,
#              "fan's": 9,
#              'hoax': 12,
#              'old': 3463,
#              'paranoia': 79,
#              'novice': 26,
#              'hope': 1300,
#              'directed': 1112,
#              'city': 864,
#              'abused': 71,
#              'backgrounds': 100,
#              'form': 705,
#              'fan': 1653,
#              'pot': 92,
#              'own': 2756,
#              'cullum': 2,
#              'becky': 11,
#              'fashioned': 133,
#              'gas': 149,
#              'john': 1572,
#              'hoodwink': 2,
#              'reveals': 175,
#              'apartment': 261,
#              'run': 1088,
#              'stand': 749,
#              'inner': 193,
#              'disturbed': 100,
#              'no': 8201,
#              "didn't": 3432,
#              'meet': 597,
#              'teacup': 4,
#              'low': 1531,
#              'estranged': 58,
#              'dreadful': 224,
#              'latest': 192,
#              'penned': 45,
#              "one's": 230,
#              'hitchcockian': 16,
#              'read': 1607,
#              'accumulated': 7,
#              'listen': 317,
#              'anticipate': 17,
#              'thing': 3725,
#              '2006': 138,
#              'predictable': 773,
#              'correspondence': 9,
#              'interesting': 2620,
#              'trait': 26,
#              'derange': 2,
#              'departure': 64,
#              'boiler': 12,
#              'celebrities': 39,
#              'nightmarish': 47,
#              'aids': 65,
#              'motives': 97,
#              'him': 5119,
#              'voice': 878,
#              'former': 465,
#              'conflicted': 37,
#              'fans': 1182,
#              'truths': 48,
#              'associates': 33,
#              'rescued': 57,
#              'investigating': 70,
#              'underlines': 12,
#              'lover': 331,
#              'unsettling': 92,
#              'airwaves': 10,
#              'whose': 850,
#              'wrote': 532,
#              'key': 386,
#              'planted': 33,
#              'baker': 103,
#              'adopted': 68,
#              'unmentioned': 4,
#              'editor': 103,
#              'doubt': 708,
#              'seed': 45,
#              'sudden': 217,
#              'decides': 500,
#              'repetitive': 114,
#              'existence': 248,
#              'emotional': 582,
#              'suddenly': 489,
#              'done': 2654,
#              'looked': 905,
#              'may': 2681,
#              'photo': 78,
#              'actresses': 331,
#              'sunshine': 75,
#              'johnson': 134,
#              'least': 2718,
#              'result': 602,
#              'caretaker': 37,
#              'bless': 40,
#              'prepared': 168,
#              'shooting': 419,
#              'foot': 213,
#              'decade': 231,
#              'killer': 908,
#              'camera': 1459,
#              'quick': 317,
#              'contracted': 11,
#              'cult': 400,
#              'online': 80,
#              'officially': 40,
#              'child': 961,
#              'dvd': 1867,
#              'incredible': 496,
#              'reviewed': 52,
#              'hour': 1040,
#              'understated': 87,
#              'chilling': 155,
#              'recommend': 1594,
#              'mind': 1792,
#              'lately': 92,
#              'god': 851,
#              'serial': 284,
#              'takes': 1937,
#              'academy': 253,
#              'portrayed': 552,
#              'play': 1728,
#              'feelings': 354,
#              'came': 1535,
#              'little': 4835,
#              'nominated': 176,
#              'constantly': 391,
#              'scary': 762,
#              'suffered': 145,
#              'smoochy': 3,
#              'death': 1511,
#              'reviews': 631,
#              'yet': 2266,
#              'especially': 2268,
#              'miss': 765,
#              'anthony': 218,
#              'actual': 707,
#              'godby': 1,
#              'sociopathic': 8,
#              'moved': 302,
#              'reports': 54,
#              'concept': 476,
#              'period': 687,
#              'generation': 217,
#              'anyone': 2281,
#              'thought': 2915,
#              'role': 2455,
#              'include': 357,
#              'among': 720,
#              'physically': 146,
#              'abuse': 172,
#              'dark': 1125,
#              'mediocre': 346,
#              'confused': 357,
#              'bombed': 37,
#              'autobiography': 37,
#              'case': 1333,
#              'dumb': 501,
#              'fraud': 43,
#              'dramas': 129,
#              'dangerous': 262,
#              'resurfaced': 3,
#              'because': 6248,
#              'sort': 1274,
#              'horrific': 156,
#              'leaves': 642,
#              'cry': 345,
#              'times': 2792,
#              'strange': 797,
#              'confirmed': 38,
#              'release': 686,
#              'exist': 278,
#              'unsettled': 9,
#              'brilliantly': 235,
#              'feeling': 1026,
#              'insomnia': 50,
#              '2008': 70,
#              'staring': 93,
#              'perhaps': 1455,
#              'exception': 392,
#              'hollywood': 1447,
#              'find': 3383,
#              'american': 1653,
#              'screen': 2100,
#              'players': 259,
#              'darkness': 166,
#              'change': 868,
#              'review': 746,
#              'stepped': 32,
#              'amount': 465,
#              'touches': 202,
#              'gloss': 20,
#              'past': 1103,
#              'forward': 629,
#              'serious': 896,
#              'lives': 1195,
#              'seems': 2902,
#              'first': 6418,
#              'we': 5545,
#              'maupins': 1,
#              'ourselves': 138,
#              'lets': 317,
#              'event': 321,
#              'forget': 670,
#              'struggle': 279,
#              'carry': 307,
#              'displayed': 97,
#              'loves': 372,
#              'fragile': 57,
#              'leading': 572,
#              'captures': 203,
#              'average': 649,
#              'another': 3606,
#              'expected': 664,
#              'please': 887,
#              'essence': 133,
#              'presence': 386,
#              'go': 4186,
#              'reminded': 329,
#              'book': 1431,
#              'strength': 231,
#              'taken': 932,
#              'opinion': 872,
#              'request': 31,
#              'trust': 307,
#              'hacks': 24,
#              'us': 2757,
#              'looks': 1998,
#              'version': 1430,
#              'chance': 968,
#              'bad': 5886,
#              'turns': 1145,
#              's': 759,
#              'around': 2982,
#              'irrevocably': 3,
#              'succeeded': 103,
#              'said': 1925,
#              'nothing': 3427,
#              'issues': 354,
#              ...})

# %%
train_sequences=token.texts_to_sequences(train_texts)
test_sequences=token.texts_to_sequences(test_texts)

# %%
print(train_texts[0])
# Out:
# Bromwell High is a cartoon comedy. It ran at the same time as some other programs about school life, such as "Teachers". My 35 years in the teaching profession lead me to believe that Bromwell High's satire is much closer to reality than is "Teachers". The scramble to survive financially, the insightful students who can see right through their pathetic teachers' pomp, the pettiness of the whole situation, all remind me of the schools I knew and their students. When I saw the episode in which a student repeatedly tried to burn down the school, I immediately recalled ......... at .......... High. A classic line: INSPECTOR: I'm here to sack one of your teachers. STUDENT: Welcome to Bromwell High. I expect that many adults of my age think that Bromwell High is far fetched. What a pity that it isn't!

# %%
print(train_sequences[0])
# Out:
# [308, 6, 3, 1068, 208, 8, 2160, 29, 1, 168, 54, 13, 45, 81, 40, 391, 109, 137, 13, 57, 149, 7, 1, 481, 68, 5, 260, 11, 2000, 6, 72, 2422, 5, 631, 70, 6, 1, 5, 2001, 1, 1530, 33, 66, 63, 204, 139, 64, 1229, 1, 4, 1, 222, 899, 28, 3021, 68, 4, 1, 9, 693, 2, 64, 1530, 50, 9, 215, 1, 386, 7, 59, 3, 1470, 3710, 798, 5, 3509, 176, 1, 391, 9, 1235, 29, 308, 3, 352, 343, 2970, 142, 129, 5, 27, 4, 125, 1470, 2372, 5, 308, 9, 532, 11, 107, 1466, 4, 57, 554, 100, 11, 308, 6, 226, 47, 3, 2231, 11, 8, 214]

# %% [markdown]
# # 让转换后数字列表长度相同

# %%
x_train=tf.keras.preprocessing.sequence.pad_sequences(train_sequences,padding='post',truncating='post',maxlen=400)
x_test=tf.keras.preprocessing.sequence.pad_sequences(test_sequences,padding='post',truncating='post',maxlen=400)
y_train=np.array(train_labels)
y_test=np.array(test_labels)

# %%
x_train.shape
# Out:
# (25000, 400)

# %% [markdown]
# # 建立模型

# %%
model=tf.keras.models.Sequential()

# %%
model.add(tf.keras.layers.Embedding(output_dim=32,
                                   input_dim=4000,
                                   input_length=400))
# Out:
# WARNING:tensorflow:From E:\anaconda\anaconda\envs\TensorFlow\lib\site-packages\tensorflow\python\keras\initializers.py:119: calling RandomUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
model.add(tf.keras.layers.Flatten())

# %%
# 用GlobalAveragePoolingID也起到平坦化效果
#model.add（tf.keras.GlobalAveragePoolingID（））

# %%
model.add(tf.keras.layers.Dense(units=256,activation='relu'))
# Out:
# WARNING:tensorflow:From E:\anaconda\anaconda\envs\TensorFlow\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
model.add(tf.keras.layers.Dropout(0.3))

# %%
model.add(tf.keras.layers.Dense(units=2,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 400, 32)           128000
# _________________________________________________________________
# flatten (Flatten)            (None, 12800)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               3277056
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 3,405,570
# Trainable params: 3,405,570
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 训练模型

# %%
model.compile(optimizer='adam',
             loss='categorical_crossentropy',
             metrics=['accuracy'])

# %%
history=model.fit(x_train,y_train,
                 validation_split=0.2,
                 epochs=10,
                 batch_size=128,
                 verbose=1)
# Out:
# Train on 20000 samples, validate on 5000 samples
# Epoch 1/10
# 20000/20000 [==============================] - 3s 159us/sample - loss: 0.5014 - acc: 0.7441 - val_loss: 0.6386 - val_acc: 0.7162
# Epoch 2/10
# 20000/20000 [==============================] - 3s 161us/sample - loss: 0.2018 - acc: 0.9241 - val_loss: 0.4715 - val_acc: 0.8150
# Epoch 3/10
# 20000/20000 [==============================] - 3s 148us/sample - loss: 0.0622 - acc: 0.9821 - val_loss: 0.6168 - val_acc: 0.8090
# Epoch 4/10
# 20000/20000 [==============================] - 3s 166us/sample - loss: 0.0127 - acc: 0.9984 - val_loss: 0.8123 - val_acc: 0.7984
# Epoch 5/10
# 20000/20000 [==============================] - 4s 187us/sample - loss: 0.0029 - acc: 0.9997 - val_loss: 0.9442 - val_acc: 0.7924
# Epoch 6/10
# 20000/20000 [==============================] - 3s 152us/sample - loss: 0.0010 - acc: 0.9999 - val_loss: 0.8123 - val_acc: 0.8264
# Epoch 7/10
# 20000/20000 [==============================] - 3s 154us/sample - loss: 6.1800e-04 - acc: 1.0000 - val_loss: 1.0444 - val_acc: 0.7994
# Epoch 8/10
# 20000/20000 [==============================] - 3s 148us/sample - loss: 3.3080e-04 - acc: 1.0000 - val_loss: 1.1077 - val_acc: 0.7960
# Epoch 9/10
# 20000/20000 [==============================] - 3s 165us/sample - loss: 2.3567e-04 - acc: 1.0000 - val_loss: 1.1819 - val_acc: 0.7892
# Epoch 10/10
# 20000/20000 [==============================] - 4s 183us/sample - loss: 1.8068e-04 - acc: 1.0000 - val_loss: 1.1754 - val_acc: 0.7946

# %% [markdown]
# # 可视化

# %% [markdown]
# # 评估准确率

# %%
test_loss,test_acc=model.evaluate(x_test,y_test,verbose=1)
print('Test Accuracy',test_acc)
# Out:
# 25000/25000 [==============================] - 1s 56us/sample - loss: 0.8492 - acc: 0.8426
# Test Accuracy 0.84256

# %% [markdown]
# # 执行预测

# %%
predictions=model.predict(x_test)
predictions[0]
# Out:
# array([0.998066  , 0.00193395], dtype=float32)

# %% [markdown]
# # 查看数据的预测结果

# %%
sentiment_dict={0:'pos',1:'neg'}
def display_test_sentiment(i):
    print(test_texts[i])
    print('label values',sentiment_dict[np.argmax(y_test[i])],
          'predict value:',sentiment_dict[np.argmax()]

# %%
display_test_sentiment(0)
# Out:
# I went and saw this movie last night after being coaxed to by a few friends of mine. I'll admit that I was reluctant to see it because from what I knew of Ashton Kutcher he was only able to do comedy. I was wrong. Kutcher played the character of Jake Fischer very well, and Kevin Costner played Ben Randall with such professionalism. The sign of a good movie is that it can toy with our emotions. This one did exactly that. The entire theater (which was sold out) was overcome by laughter during the first half of the movie, and were moved to tears during the second half. While exiting the theater I not only saw many women in tears, but many full grown men as well, trying desperately not to let anyone see them crying. This movie was great, and I suggest that you go see it before you judge.
# label values: pos predict value: pos

# %% [markdown]
# 网上找评论来试验
